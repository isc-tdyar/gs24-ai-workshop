# %%
import os

os.environ['STREAMLIT_GENERAL_EMAIL'] = ""
os.environ['STREAMLIT_THEME_PRIMARYCOLOR'] = "#5863ff"

# %%
# %%bash
# # If you're using a container, mac, or linux machine --- run this cell
# streamlit run application.py --server.port 8080

# %%
# %%cmd
# @REM If you're using a windows machine, run this cell
# streamlit run application.py --server.port 8080
# Out:
# Microsoft Windows [Version 10.0.22000.2538]
# (c) Microsoft Corporation. All rights reserved.
#
# c:\Users\nmitchko\Documents\Sales\Events\2024\gs24-ai-workshop\exercise\financial>@REM If you're using a windows machine, run this cell
#
# c:\Users\nmitchko\Documents\Sales\Events\2024\gs24-ai-workshop\exercise\financial>streamlit run application.py --server.port 8080
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8080
#   Network URL: http://192.168.101.160:8080
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain\embeddings\__init__.py:29: LangChainDeprecationWarning: Importing embeddings from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.embeddings import OpenAIEmbeddings`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# []
# 2024-05-07 12:38:27.312 Uncaught app exception
# Traceback (most recent call last):
#   File "C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\streamlit\runtime\scriptrunner\script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "C:\Users\nmitchko\Documents\Sales\Events\2024\gs24-ai-workshop\exercise\financial\application.py", line 175, in <module>
#     first_relevant_doc = relevant_docs[0]
#                          ~~~~~~~~~~~~~^^^
# IndexError: list index out of range
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain\embeddings\__init__.py:29: LangChainDeprecationWarning: Importing embeddings from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.embeddings import OpenAIEmbeddings`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# [(Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.171249366806152), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.171283553244417), (Document(page_content='BAML warns of profit pressure for Hormel', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 42}), 0.206176269438001), (Document(page_content='BAML warns of profit pressure for Hormel', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 42}), 0.206201226498489)]
# 2024-05-07 12:39:14.840 Uncaught app exception
# Traceback (most recent call last):
#   File "C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\streamlit\runtime\scriptrunner\script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "C:\Users\nmitchko\Documents\Sales\Events\2024\gs24-ai-workshop\exercise\financial\application.py", line 176, in <module>
#     urls = extractor.find_urls(first_relevant_doc)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\urlextract\urlextract_core.py", line 958, in find_urls
#     url = next(urls, "")
#           ^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\urlextract\urlextract_core.py", line 876, in gen_urls
#     matched_tlds = self._tlds_re.findall(text)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: expected string or bytes-like object, got 'list'
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain\embeddings\__init__.py:29: LangChainDeprecationWarning: Importing embeddings from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.embeddings import OpenAIEmbeddings`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# [(Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.171249366806152), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.171283553244417), (Document(page_content='BAML warns of profit pressure for Hormel', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 42}), 0.206176269438001), (Document(page_content='BAML warns of profit pressure for Hormel', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 42}), 0.206201226498489)]
# ['https://t.co/bd0xbFGjkT', 'https://t.co/bd0xbFGjkT']
# 2024-05-07 12:40:01.080 Uncaught app exception
# Traceback (most recent call last):
#   File "C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain_community\document_loaders\url_selenium.py", line 51, in __init__
#     import unstructured  # noqa:F401
#     ^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\streamlit\runtime\scriptrunner\script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "C:\Users\nmitchko\Documents\Sales\Events\2024\gs24-ai-workshop\exercise\financial\application.py", line 178, in <module>
#     web_loader = SeleniumURLLoader(urls[0])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain_community\document_loaders\url_selenium.py", line 53, in __init__
#     raise ImportError(
# ImportError: unstructured package not found, please install it with `pip install unstructured`
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain\embeddings\__init__.py:29: LangChainDeprecationWarning: Importing embeddings from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.embeddings import OpenAIEmbeddings`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# []
# []
# 2024-05-07 12:40:49.069 Uncaught app exception
# Traceback (most recent call last):
#   File "C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\streamlit\runtime\scriptrunner\script_runner.py", line 584, in _run_script
#     exec(code, module.__dict__)
#   File "C:\Users\nmitchko\Documents\Sales\Events\2024\gs24-ai-workshop\exercise\financial\application.py", line 178, in <module>
#     web_loader = SeleniumURLLoader(urls[0])
#                                    ~~~~^^^
# IndexError: list index out of range
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain\embeddings\__init__.py:29: LangChainDeprecationWarning: Importing embeddings from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.embeddings import OpenAIEmbeddings`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# [(Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.154501619285499), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.154501619285499), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.154559436048877), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.154559436048877)]
# ['https://t.co/bd0xbFGjkT', 'https://t.co/bd0xbFGjkT', 'https://t.co/bd0xbFGjkT', 'https://t.co/bd0xbFGjkT']
# Error fetching or processing h, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing t, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing t, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing p, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing s, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing :, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing /, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing /, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing t, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing ., exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing c, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing o, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing /, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing b, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing d, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing 0, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing x, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing b, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing F, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing G, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing j, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing k, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
#
# Error fetching or processing T, exception: Message: invalid argument
#   (Session info: chrome-headless-shell=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7B3FB1502+60802]
# 	(No symbol) [0x00007FF7B3F2AC02]
# 	(No symbol) [0x00007FF7B3DE7B13]
# 	(No symbol) [0x00007FF7B3DD05E0]
# 	(No symbol) [0x00007FF7B3DCEC3D]
# 	(No symbol) [0x00007FF7B3DCF22C]
# 	(No symbol) [0x00007FF7B3DEA9F9]
# 	(No symbol) [0x00007FF7B3E7AB7E]
# 	(No symbol) [0x00007FF7B3E5AB7A]
# 	(No symbol) [0x00007FF7B3E7A224]
# 	(No symbol) [0x00007FF7B3E5A923]
# 	(No symbol) [0x00007FF7B3E28FEC]
# 	(No symbol) [0x00007FF7B3E29C21]
# 	GetHandleVerifier [0x00007FF7B42B411D+3217821]
# 	GetHandleVerifier [0x00007FF7B42F60B7+3488055]
# 	GetHandleVerifier [0x00007FF7B42EF03F+3459263]
# 	GetHandleVerifier [0x00007FF7B406B846+823494]
# 	(No symbol) [0x00007FF7B3F35F9F]
# 	(No symbol) [0x00007FF7B3F30EC4]
# 	(No symbol) [0x00007FF7B3F31052]
# 	(No symbol) [0x00007FF7B3F218A4]
# 	BaseThreadInitThunk [0x00007FFCE18C53E0+16]
# 	RtlUserThreadStart [0x00007FFCE1B6485B+43]
# []
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# > Entering new ConversationChain chain...
# Prompt after formatting:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
#
# Human:
# Prompt: What is the outlook for beyond meat
#
# Relevant Documents: ['$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ']
#
# You should only make use of the provided Relevant Documents. They are important information belonging to the user, and it is important that any advice you give is grounded in these documents. If the documents are irrelevant to the question, simply state that you do not have the relevant information available in the database.
#
# AI:
#
# > Finished chain.
# {'input': "\nPrompt: What is the outlook for beyond meat\n\nRelevant Documents: ['$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ']\n\nYou should only make use of the provided Relevant Documents. They are important information belonging to the user, and it is important that any advice you give is grounded in these documents. If the documents are irrelevant to the question, simply state that you do not have the relevant information available in the database.\n                ", 'history': '', 'response': 'Based on the relevant documents provided, it seems that JPMorgan has reeled in expectations on Beyond Meat. This could potentially impact the outlook for the company. However, without more specific information or analysis, it is difficult to provide a definitive answer on the outlook for Beyond Meat. It may be worth looking into additional sources or expert opinions to get a clearer picture of the situation.'}
# ['https://t.co/bd0xbFGjkT']
# C:\Users\nmitchko\AppData\Roaming\Python\Python311\site-packages\langchain\embeddings\__init__.py:29: LangChainDeprecationWarning: Importing embeddings from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.embeddings import OpenAIEmbeddings`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# [(Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.151776554758974), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.151776554758974), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.151837453145233), (Document(page_content='$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT', metadata={'source': 'C:\\Users\\nmitchko\\Documents\\Sales\\Events\\2024\\gs24-ai-workshop\\exercise\\financial\\data\\financial\\tweets_all.jsonl', 'seq_num': 1}), 0.151837453145233)]
# ['https://t.co/bd0xbFGjkT', 'https://t.co/bd0xbFGjkT', 'https://t.co/bd0xbFGjkT', 'https://t.co/bd0xbFGjkT']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nmitchko\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\nmitchko\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [Document(page_content='Before we continue...\n\nPress & Hold to confirm you are\n\na human (and not a bot).\n\nHaving a problem?\n\nReference ID 57aae97a-0c91-11ef-8b30-7524e4741f46\n\nReport a problem\n\nExperiencing issues with this page? please let us know:\n\nYou can contact us for assistance. You should use Ref ID\n\n: 57aae97a-0c91-11ef-8b30-7524e4741f46\n\nYou can also send us your feedback:\n\nExperiencing other issues?\n\nThank you for the feedback', metadata={'source': 'https://t.co/bd0xbFGjkT', 'title': 'Access to this page has been denied', 'description': 'px-captcha', 'language': 'en'})]
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
#
# Human:
# Prompt: What is beyond meat's expectation
#
# Relevant Documents: ['$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ']
#
# You should only make use of the provided Relevant Documents. They are important information belonging to the user, and it is important that any advice you give is grounded in these documents. If the documents are irrelevant to the question, simply state that you do not have the relevant information available in the database.
#
# AI:
#
# > Finished chain.
# {'input': "\nPrompt: What is beyond meat's expectation\n\nRelevant Documents: ['$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ', '$BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT ']\n\nYou should only make use of the provided Relevant Documents. They are important information belonging to the user, and it is important that any advice you give is grounded in these documents. If the documents are irrelevant to the question, simply state that you do not have the relevant information available in the database.\n                ", 'history': '', 'response': 'Based on the provided documents, it appears that JPMorgan has adjusted its expectations regarding Beyond Meat, specifically indicating a reeling in or reduction of these expectations. Unfortunately, the documents do not provide specific details about what these adjusted expectations entail or the reasons behind the adjustment. For more detailed information, you might want to look at the full article linked in the tweets or consult additional sources.'}
# ['https://t.co/bd0xbFGjkT']
